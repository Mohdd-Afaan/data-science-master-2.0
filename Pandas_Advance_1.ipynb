# %% [markdown]
# <a href="https://colab.research.google.com/github/Mohdd-Afaan/data-science-master-2.0/blob/main/Pandas_Advance_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Ans:
# 1) Creating a DataFrame:
#   Pandas DataFrame is a two-dimensional labeled data structure with columns that can be of different types.

# %%
import pandas as pd

# %%
var_1 = {'Name':['Mike','Mario','Martina'],'Age':[81,19,20]}
df_1 = pd.DataFrame(data=var_1)
print(df_1)
# Out:
#       Name  Age
# 0     Mike   81
# 1    Mario   19
# 2  Martina   20

# %% [markdown]
# 2) Reading Data from a CSV file:
#   Pandas can read data from various sources, including CSV files.

# %%
pd.read_csv('emaple.csv')  #its just an example to read csv

# %% [markdown]
# 3) Data Selection and Slicing:
#   Pandas provides various methods to select and slice data.

# %%
dat = df_1['Age']
print(dat)
# Out:
# 0    81
# 1    19
# 2    20
# Name: Age, dtype: int64

# %% [markdown]
# 4) Data Aggregation:
#   Pandas allows you to perform aggregation operations on data, such as calculating mean, sum, etc.

# %%
a = df_1['Age'].mean()
print(a)
# Out:
# 40.0

# %% [markdown]
# 5) Data Cleaning:
# Pandas provides functions to handle missing data.

# %%
b = df_1.isnull()
print(f"{b}")
# Out:
#     Name    Age
# 0  False  False
# 1  False  False
# 2  False  False

# %% [markdown]
# Q2. Given a Pandas DataFrame df with columns 'A', 'B', and 'C', write a Python function to re-index the
# DataFrame with a new index that starts from 1 and increments by 2 for each row.

# %%
var_2 = {'A':[5.48,26,1564,321654],'B':[6545631,524165453,53464,346],'C':[5416854,234654,125468,54658]}
df_2 = pd.DataFrame(data=var_2)
print(df_2)
# Out:
#            A          B        C
# 0       5.48    6545631  5416854
# 1      26.00  524165453   234654
# 2    1564.00      53464   125468
# 3  321654.00        346    54658

# %%
def dataframe_reindex_inplace(df):
  df.reset_index(drop=True,inplace=True)
  new_index = pd.Index(list(range(1,len(df)*3,3)))
  df.set_index(new_index,inplace=True)

# %%
dataframe_reindex_inplace(df_2)

# %%
df_2
# Out:
#             A          B        C
# 1        5.48    6545631  5416854
# 4       26.00  524165453   234654
# 7     1564.00      53464   125468
# 10  321654.00        346    54658

# %% [markdown]
# Q3. You have a Pandas DataFrame df with a column named 'Values'. Write a Python function that
# iterates over the DataFrame and calculates the sum of the first three values in the 'Values' column. The
# function should print the sum to the console.

# %%
var_3 = {'A':['a','b','c','d'],'Values':[6,5,4,3],'C':[5,2,1,8]}
df_3 = pd.DataFrame(data=var_3)
print(df_3)
# Out:
#    A  Values  C
# 0  a       6  5
# 1  b       5  2
# 2  c       4  1
# 3  d       3  8

# %%
def sum_first_3(df):
  res = df['Values'][:3].sum()
  print(res)

# %%
sum_first_3(df_3)
# Out:
# 15

# %% [markdown]
# Q4. Given a Pandas DataFrame df with a column 'Text', write a Python function to create a new column
# 'Word_Count' that contains the number of words in each row of the 'Text' column.

# %%
var_4 = {'Text':['Egg','Mars','Kind','Dino'],'Values':[6,5,4,3]}
df_4 = pd.DataFrame(data=var_4)
print(df_4)
# Out:
#    Text  Values
# 0   Egg       6
# 1  Mars       5
# 2  Kind       4
# 3  Dino       3

# %%
def Word_Count_Func(df):
  values = [len(i) for i in df['Text'] ]
  df['Word_Count'] = values

# %%
Word_Count_Func(df_4)

# %%
df_4
# Out:
#    Text  Values  Word_Count
# 0   Egg       6           3
# 1  Mars       5           4
# 2  Kind       4           4
# 3  Dino       3           4

# %% [markdown]
# Q5. How are DataFrame.size() and DataFrame.shape() different?

# %% [markdown]
# Ans: DataFrame.size returns the total number of elements in the DataFrame. It represents the product of the number of rows and the number of columns.
# It is equivalent to the total number of cells or entries in the DataFrame.
# The result is an integer. DataFrame.shape returns a tuple representing the dimensions of the DataFrame. The tuple contains two elements: the number of rows and the number of columns.It provides information about the structure of the DataFrame.The result is a tuple (number of rows, number of columns).

# %%
print(df_4.shape)
print(df_4.size)
# Out:
# (4, 3)
# 12

# %% [markdown]
# Q6. Which function of pandas do we use to read an excel file?

# %%
pd.read_excel("path") # the path replaces the real file path

# %% [markdown]
# Q7. You have a Pandas DataFrame df that contains a column named 'Email' that contains email
# addresses in the format 'username@domain.com'. Write a Python function that creates a new column
# 'Username' in df that contains only the username part of each email address.
# The username is the part of the email address that appears before the '@' symbol. For example, if the
# email address is 'john.doe@example.com', the 'Username' column should contain 'john.doe'. Your
# function should extract the username from each email address and store it in the new 'Username'
# column.

# %%
data = {'Email': ['Jhonny@example.com', 'katey@example.com', 'mike@example.com', 'Mario@example.com'],'Column2':['value1', 'value2', 'value3', 'value4'],'Column3':[10, 20, 30, 40]}
df_5 = pd.DataFrame(data)
print(df_5)
# Out:
#                 Email Column2  Column3
# 0  Jhonny@example.com  value1       10
# 1   katey@example.com  value2       20
# 2    mike@example.com  value3       30
# 3   Mario@example.com  value4       40

# %%
def email_username(df):
  values = [i.split('@')[0]for i in df_5['Email']]
  df['Username'] = values

# %%
email_username(df_5)

# %%
df_5
# Out:
#                 Email Column2  Column3 Username
# 0  Jhonny@example.com  value1       10   Jhonny
# 1   katey@example.com  value2       20    katey
# 2    mike@example.com  value3       30     mike
# 3   Mario@example.com  value4       40    Mario

# %% [markdown]
# Q8. You have a Pandas DataFrame df with columns 'A', 'B', and 'C'. Write a Python function that selects
# all rows where the value in column 'A' is greater than 5 and the value in column 'B' is less than 10. The
# function should return a new DataFrame that contains only the selected rows.

# %%
var_5 = {'A':[3,8,6,2,9],'B':[5,2,9,3,1],'C':[1,7,4,5,2]}
df_6 = pd.DataFrame(var_5)

# %%
def new_dataframe(df):
  return df[(df['A']>5) & (df['B']<10)]

# %%
new_dataframe(df_6)
# Out:
#    A  B  C
# 1  8  2  7
# 2  6  9  4
# 4  9  1  2

# %% [markdown]
# Q9. Given a Pandas DataFrame df with a column 'Values', write a Python function to calculate the mean,
# median, and standard deviation of the values in the 'Values' column.

# %%
# useing df_3 created in q.no 3
def mean_median_standard_deviation(df):
  x = df['Values'].mean()
  y = df['Values'].median()
  z = df['Values'].std()
  return x,y,z

# %%
mean_median_standard_deviation(df_3)
# Out:
# (4.5, 4.5, 1.2909944487358056)

# %% [markdown]
# Q10. Given a Pandas DataFrame df with a column 'Sales' and a column 'Date', write a Python function to
# create a new column 'MovingAverage' that contains the moving average of the sales for the past 7 days
# for each row in the DataFrame. The moving average should be calculated using a window of size 7 and
# should include the current day.

# %%
import random
from datetime import datetime, timedelta

start_date = datetime(2023, 12, 1)
end_date = datetime(2023, 12, 31)
date_range = [start_date + timedelta(days=i) for i in range((end_date - start_date).days + 1)]

sales_data = {'Sales': [random.randint(50, 200) for _ in range(len(date_range))],
              'Date': date_range}

df_7 = pd.DataFrame(sales_data)

print(df_7)
# Out:
#     Sales       Date
# 0     116 2023-12-01
# 1     154 2023-12-02
# 2     109 2023-12-03
# 3      81 2023-12-04
# 4     124 2023-12-05
# 5      64 2023-12-06
# 6     105 2023-12-07
# 7     132 2023-12-08
# 8     101 2023-12-09
# 9     150 2023-12-10
# 10    161 2023-12-11
# 11    183 2023-12-12
# 12    193 2023-12-13
# 13    154 2023-12-14
# 14     53 2023-12-15
# 15     69 2023-12-16
# 16    128 2023-12-17
# 17     85 2023-12-18
# 18     81 2023-12-19
# 19    143 2023-12-20
# 20    107 2023-12-21
# 21    180 2023-12-22
# 22     80 2023-12-23
# 23    129 2023-12-24
# 24    164 2023-12-25
# 25    123 2023-12-26
# 26    189 2023-12-27
# 27     83 2023-12-28
# 28    135 2023-12-29
# 29    159 2023-12-30
# 30    142 2023-12-31

# %%
def moving_avg(df,window_size):
  df['Date'] = pd.to_datetime(df['Date'])
  df.sort_values(by='Date', inplace= True)
  df['MovingAverage']= df['Sales'].rolling(window=window_size,min_periods=1).mean()

# %%
moving_avg(df_7,7)

# %%
df_7
# Out:
#     Sales       Date  MovingAverage
# 0     116 2023-12-01     116.000000
# 1     154 2023-12-02     135.000000
# 2     109 2023-12-03     126.333333
# 3      81 2023-12-04     115.000000
# 4     124 2023-12-05     116.800000
# 5      64 2023-12-06     108.000000
# 6     105 2023-12-07     107.571429
# 7     132 2023-12-08     109.857143
# 8     101 2023-12-09     102.285714
# 9     150 2023-12-10     108.142857
# 10    161 2023-12-11     119.571429
# 11    183 2023-12-12     128.000000
# 12    193 2023-12-13     146.428571
# 13    154 2023-12-14     153.428571
# 14     53 2023-12-15     142.142857
# 15     69 2023-12-16     137.571429
# 16    128 2023-12-17     134.428571
# 17     85 2023-12-18     123.571429
# 18     81 2023-12-19     109.000000
# 19    143 2023-12-20     101.857143
# 20    107 2023-12-21      95.142857
# 21    180 2023-12-22     113.285714
# 22     80 2023-12-23     114.857143
# 23    129 2023-12-24     115.000000
# 24    164 2023-12-25     126.285714
# ...

# %% [markdown]
# Q11. You have a Pandas DataFrame df with a column 'Date'. Write a Python function that creates a new
# column 'Weekday' in the DataFrame. The 'Weekday' column should contain the weekday name (e.g.
# Monday, Tuesday) corresponding to each date in the 'Date' column.

# %%
var_6 = {'Date':['2023-01-01','2023-01-02','2023-01-03','2023-01-04','2023-01-05']}
df_8 = pd.DataFrame(data=var_6)

# %%
df_8['Date']=pd.to_datetime(df_8['Date'])

# %%
def to_week_day(df):
  df['Date']= pd.to_datetime(df['Date'])
  df['Day']=df['Date'].dt.day_name()

# %%
to_week_day(df_8)
df_8
# Out:
#         Date        Day
# 0 2023-01-01     Sunday
# 1 2023-01-02     Monday
# 2 2023-01-03    Tuesday
# 3 2023-01-04  Wednesday
# 4 2023-01-05   Thursday

# %% [markdown]
# Q12. Given a Pandas DataFrame df with a column 'Date' that contains timestamps, write a Python
# function to select all rows where the date is between '2023-01-01' and '2023-01-31'.

# %%
start_date = datetime(2023, 1, 1)
end_date = datetime(2023, 11, 30)
date_range = [start_date + timedelta(days=i) for i in range((end_date - start_date).days + 1)]
var_7 = {'Date': date_range}
df_9= pd.DataFrame(data= var_7)
df_9
# Out:
#           Date
# 0   2023-01-01
# 1   2023-01-02
# 2   2023-01-03
# 3   2023-01-04
# 4   2023-01-05
# ..         ...
# 329 2023-11-26
# 330 2023-11-27
# 331 2023-11-28
# 332 2023-11-29
# 333 2023-11-30
#
# [334 rows x 1 columns]

# %%
def timestamp_func(df,start_date,end_date):
  return df.loc[(df['Date']>=start_date)&(df['Date']<end_date)]

# %%
timestamp_func(df_9,'2023-01-01','2023-01-31')
# Out:
#          Date
# 0  2023-01-01
# 1  2023-01-02
# 2  2023-01-03
# 3  2023-01-04
# 4  2023-01-05
# 5  2023-01-06
# 6  2023-01-07
# 7  2023-01-08
# 8  2023-01-09
# 9  2023-01-10
# 10 2023-01-11
# 11 2023-01-12
# 12 2023-01-13
# 13 2023-01-14
# 14 2023-01-15
# 15 2023-01-16
# 16 2023-01-17
# 17 2023-01-18
# 18 2023-01-19
# 19 2023-01-20
# 20 2023-01-21
# 21 2023-01-22
# 22 2023-01-23
# 23 2023-01-24
# 24 2023-01-25
# 25 2023-01-26
# 26 2023-01-27
# 27 2023-01-28
# 28 2023-01-29
# 29 2023-01-30

# %% [markdown]
# Q13. To use the basic functions of pandas, what is the first and foremost necessary library that needs to
# be imported?

# %% [markdown]
# Ans: The first and foremost library that needs to be imported to use the basic functions of pandas is, unsurprisingly, the pandas library itself.
